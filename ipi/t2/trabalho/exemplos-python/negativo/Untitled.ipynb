# %% [markdown]
# ## Negativos de Imagens Digitais

# %%
import numpy as np              # biblioteca eficiente para operacoes matriciais
import matplotlib.pyplot as plt # plotar imagens e gráficos
import cv2                      # varios recursos para processamento de imagens

# %%
# g(x,y) = 255 - f(x,y)
img = plt.imread("Ensino/Disciplinas/ProcImagens/Aula02/exemplos-python/negativo/breast_digital_Xray.tif)
print(type(img))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # g(x,y) = 255 - f(x,y)
# ----> 2 img = plt.imread("Ensino/Disciplinas/ProcImagens/Aula02/exemplos-python/negativo/breast_digital_Xray.tif")
#       3 print(type(img))
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/matplotlib/pyplot.py:2389, in imread(fname, format)
#    2385 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2386 def imread(
#    2387         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2388 ) -> np.ndarray:
# -> 2389     return matplotlib.image.imread(fname, format)
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/matplotlib/image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
# ...
